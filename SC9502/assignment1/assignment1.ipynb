# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## Question 1

# %% [markdown]
# Computing can generally be measured using the number of *floating point operations* performed in a *second*, known as "FLOPS". This is distinct from the number typically associated with CPUs, which is the clock frequency. The difference is that the clock frequency measures the number of cycles per second (i.e. times the CPU can execute an instruction), whereas the FLOPS measures the number of floating point operations that can be performed in one second, where multiple floating point operations can per performed per cycle.
#
# We can compare the various computing platforms from the past and present using this generic measure. The comparison will ignore the computing power of graphics processors, and only compare the central processing units (CPUs).
#
# Supercomputers in the 1990s took a massive leap by incorporating thousands of processors compared to the mere 4 CPUs of the previous decade's flagship, the Cray-2 (Anderson, 1988). Two notable examples of supercomputers from the 1990s are: the Intel Paragon XP/S (Esser, 1993), where the XP/S 140 achieved a peak performance of 143 GFLOPS and claimed the number one position in 1994; and the *Numerical Wind Tunnel* built in Japan with a peak performance of 170 GFLOPS ($10^9$ FLOPS) (Hirose, 1989), snatching number one position from the XP/S until it was dethroned in 1995 (TOP500.org).
#
# The FLOPS measurements of supercomputers of this era was typically determined from the LINPACK benchmark test, which is based on evaluating the performance of solving a general dense matrix problem (Dongarra, 2003), and is still maintained today. The computer used to write this assignment achieved a maximum measurement of 239 GFLOPs on the benchmark (using an Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz).
#
# Another benchmark is called the Whetstone benchmark, developed in 1976 and the first one made specifically for benchmarking.
# Whestone benchmark results were compiled for various ARM CPUs used in Android devices, shown at the link [here](http://www.roylongbottom.org.uk/android%20benchmarks.htm#anchor3). Part of the table from that link is copied below:
#
# ```text
#     System   ARM   MHz Android MWIPS  ------MFLOPS-------
#              CPU        Build           1      2      3
#
#     Original ARM Version
#     A1    Z3745   1866  4.4.2 1075.4  373.8  311.5  284.5
#     A1    Z3745   1866  5.0    773.4  548.6  371.9  368.2
#     A5    Z8300   1840  5.1    747.7  475.7  376.8  315.2
#     T7    v7-A9   1200  4.1.2 1115.0  271.3  250.7  256.4
#     T22   v8-A53  1300  5.0.2 1433.7  348.0  319.3  308.2
#     T11   v7-A15  1700  4.2.2 1477.7  363.9  220.6  307.5
#     T21   QU-800  2150  4.4.3 2035.1  665.7  640.0  531.6
# ```
#
# The system key from the first column can be looked up [here](http://www.roylongbottom.org.uk/android%20benchmarks.htm#anchor50).
#
#
#
# - R. E. Anderson, R. G. Grimes, H. D. Simon, Performance comparison of the CRAY X-MP/24 with SDD and the CRAY-2. The Journal of Supercomputing 1, 409–419 (1988). [doi](https://doi.org/10.1007/bf00128490)
# - Hirose, N., & Fukuda, M. (1989). Numerical Wind Tunnel (NWT) and CFD research at National Aerospace Laboratory. *Proceedings High Performance Computing on the Information Superhighway. HPC Asia ’97*. [doi](https://doi.org/10.1109/hpc.1997.592130)
# - Esser, R., & Knecht, R. (1993). Intel Paragon XP/S - Architecture and Software Environment. In Informatik aktuell (pp. 121–141). *Springer Berlin Heidelberg*. [doi](https://doi.org/10.1007/978-3-642-78348-7_13)
# - Bönniger, T., Esser, R., & Krekel, D. (1995). CM-5E, KSR2, Paragon XP/S: A comparative description of massively parallel computers. *Parallel Computing*, 21(2), 199–232. [doi](https://doi.org/10.1016/0167-8191(94)00075-l)
# - Dongarra, J. J., Luszczek, P., & Petitet, A. (2003). The LINPACK Benchmark: past, present and future. *Concurrency and Computation: Practice and Experience*, 15(9), 803–820. [doi](https://doi.org/10.1002/cpe.728)
# - TOP500.org (n.d.). *No. 1 system in June 1994.* https://www.top500.org/resources/top-systems/intel-xps-140-paragon-sandia-national-labs/
# - bakerlab.org. (n.d.). *CPU performance*. https://boinc.bakerlab.org/rosetta/cpu_list.php
# - Weicker, R. P. (1990). An overview of common benchmarks. Computer, 23(12), 65–75. [doi](https://doi.org/10.1109/2.62094)

# %% [markdown]
# ## Question 2

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Question 3-13

# %% [markdown]
# #### 5.1

# %% [markdown]
# ```text
# zirconix@Karakum:~$ cat /proc/cpuinfo
# processor       : 0
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 0
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 1
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 0
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 2
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 1
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 3
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 1
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 4
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 2
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 5
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 2
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 6
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 3
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 7
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 3
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 8
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 4
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 9
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 4
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 10
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 5
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
#
# processor       : 11
# vendor_id       : GenuineIntel
# cpu family      : 6
# model           : 79
# model name      : Intel(R) Core(TM) i7-6800K CPU @ 3.40GHz
# stepping        : 1
# microcode       : 0xffffffff
# cpu MHz         : 3401.000
# cache size      : 256 KB
# physical id     : 0
# siblings        : 12
# core id         : 5
# cpu cores       : 6
# apicid          : 0
# initial apicid  : 0
# fpu             : yes
# fpu_exception   : yes
# cpuid level     : 6
# wp              : yes
# flags           : fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand lahf_lm abm 3dnowprefetch fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt ibrs ibpb stibp ssbd
# bogomips        : 6802.00
# clflush size    : 64
# cache_alignment : 64
# address sizes   : 36 bits physical, 48 bits virtual
# power management:
# ```

# %% [markdown]
# #### 5.2

# %% [markdown]
# ```text
# zirconix@Karakum:~$ ls /bin/n?n*
# /bin/nano
# ```

# %% [markdown]
# #### 5.3

# %% [markdown]
# ```text
# zirconix@Karakum:~$ ls -ld /usr/*
# drwxr-xr-x 1 root root 4096 Jan  7 11:45 /usr/bin
# drwxr-xr-x 1 root root 4096 Apr 18  2022 /usr/games
# drwxr-xr-x 1 root root 4096 Nov 22 16:37 /usr/include
# drwxr-xr-x 1 root root 4096 Jan  7 11:45 /usr/lib
# drwxr-xr-x 1 root root 4096 Nov 22 16:36 /usr/lib32
# drwxr-xr-x 1 root root 4096 Nov 22 16:36 /usr/lib64
# drwxr-xr-x 1 root root 4096 Nov 22 16:37 /usr/libexec
# drwxr-xr-x 1 root root 4096 Nov 22 16:36 /usr/libx32
# drwxr-xr-x 1 root root 4096 Nov 22 16:36 /usr/local
# drwxr-xr-x 1 root root 4096 Jan  7 11:45 /usr/sbin
# drwxr-xr-x 1 root root 4096 Nov 22 16:37 /usr/share
# drwxr-xr-x 1 root root 4096 Apr 18  2022 /usr/src
# ```

# %% [markdown]
# #### 5.4

# %% [markdown]
# ```text
# zirconix@Karakum:~$ du -sh /bin/{x,y}* | sort -h
# 0       /bin/x86_64
# 0       /bin/x86_64-linux-gnu-gold
# 0       /bin/x86_64-linux-gnu-ld
# 0       /bin/xdg-user-dir
# 0       /bin/xzcat
# 0       /bin/xzcmp
# 0       /bin/xzegrep
# 0       /bin/xzfgrep
# 0       /bin/ypdomainname
# 4.0K    /bin/xzless
# 4.0K    /bin/xzmore
# 8.0K    /bin/xsubpp
# 8.0K    /bin/xzdiff
# 8.0K    /bin/xzgrep
# 20K     /bin/xxd
# 24K     /bin/x86_64-linux-gnu-c++filt
# 28K     /bin/x86_64-linux-gnu-addr2line
# 28K     /bin/xdg-user-dirs-update
# 32K     /bin/x86_64-linux-gnu-size
# 32K     /bin/x86_64-linux-gnu-strings
# 32K     /bin/yes
# 36K     /bin/x86_64-linux-gnu-elfedit
# 44K     /bin/x86_64-linux-gnu-nm
# 56K     /bin/x86_64-linux-gnu-ar
# 56K     /bin/x86_64-linux-gnu-ranlib
# 56K     /bin/xauth
# 64K     /bin/xargs
# 84K     /bin/xz
# 112K    /bin/x86_64-linux-gnu-gprof
# 164K    /bin/x86_64-linux-gnu-objcopy
# 164K    /bin/x86_64-linux-gnu-strip
# 372K    /bin/x86_64-linux-gnu-objdump
# 460K    /bin/x86_64-linux-gnu-as
# 764K    /bin/x86_64-linux-gnu-readelf
# 1.7M    /bin/x86_64-linux-gnu-ld.bfd
# 1.9M    /bin/x86_64-linux-gnu-dwp
# 3.1M    /bin/x86_64-linux-gnu-ld.gold
# ```

# %% [markdown]
# #### 5.5

# %% [markdown]
# ```text
# zirconix@Karakum:~$ cd TESTING
# zirconix@Karakum:~/TESTING$ touch mytext_1.txt mytext_2.txt
# zirconix@Karakum:~/TESTING$ vi mytext_1.txt
# zirconix@Karakum:~/TESTING$ vi mytext_2.txt
# zirconix@Karakum:~/TESTING$ diff mytext_1.txt mytext_2.txt
# 1c1
# < This is my first file.
# ---
# > This is my second file.
# ```
# ![file1 inserted](images/Screenshot%202024-01-28%2013.24.53.png "file1 inserted")
# ![file1 saving](images/Screenshot%202024-01-28%2013.25.12.png "file1 saving")
# ![file2 saving](images/Screenshot%202024-01-28%2013.25.38.png "file2 saving")

# %% [markdown]
# #### 5.6

# %% [markdown]
# ```text
# zirconix@Karakum:~/TESTING$ echo "This text goes in mytext_1." >> mytext_1.txt
# zirconix@Karakum:~/TESTING$ diff mytext_1.txt mytext_2.txt
# 1,2c1
# < This is my first file.
# < This text goes in mytext_1.
# ---
# > This is my second file.
# ```

# %% [markdown]
# #### 5.7

# %% [markdown]
# ```text
# zirconix@Karakum:~/TESTING$ ln -s mytext_1.txt mytext_temp.txt
# zirconix@Karakum:~/TESTING$ cat mytext_temp.txt
# This is my first file.
# This text goes in mytext_1.
# zirconix@Karakum:~/TESTING$ vi mytext_1.txt
# zirconix@Karakum:~/TESTING$ cat mytext_temp.txt
# This is my first file.
# This text goes in mytext_1.
# Written after linking.
# ```

# %% [markdown]
# #### 5.8

# %% [markdown]
# ```text
# zirconix@Karakum:~/TESTING$ rm -i mytex*
# rm: remove regular file 'mytext_1.txt'? y
# rm: remove regular file 'mytext_2.txt'? y
# rm: remove symbolic link 'mytext_temp.txt'? y
# zirconix@Karakum:~/TESTING$ cd ..
# zirconix@Karakum:~$ rmdir TESTING/
# ```

# %% [markdown]
# #### 5.9

# %% [markdown]
# ```text
# zirconix@Karakum:~$ ps -e
#   PID TTY          TIME CMD
#     1 ?        00:00:00 init
#   110 tty1     00:00:00 init
#   111 tty1     00:00:00 bash
#   184 tty2     00:00:00 init
#   185 tty2     00:00:00 bash
#   201 tty1     00:00:00 vi
#   202 tty2     00:00:00 ps
# zirconix@Karakum:~$ kill 201
# zirconix@Karakum:~$ ps -e
#   PID TTY          TIME CMD
#     1 ?        00:00:00 init
#   110 tty1     00:00:00 init
#   111 tty1     00:00:00 bash
#   184 tty2     00:00:00 init
#   185 tty2     00:00:00 bash
#   203 tty2     00:00:00 ps
# ```
# ![vi open](images/Screenshot%202024-01-28%2013.33.03.png "vi open")
# ![vi closed](images/Screenshot%202024-01-28%2013.33.36.png "vi closed")

# %% [markdown]
# #### 5.10

# %% [markdown]
# ![answer](images/Screenshot%202024-01-28%2013.52.00.png "answer")

# %% [markdown]
# #### 5.11

# %% [markdown]
# ```text
# zirconix@Karakum:~$ ps aux --sort -rss
# USER       PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# zirconix   241  0.2  0.0  19892  5440 tty2     S    13:49   0:00 ssh -L 5901:localho
# zirconix   111  0.0  0.0  14248  4064 tty1     S    13:23   0:00 -bash
# zirconix   219  0.0  0.0  14248  3804 tty2     S    13:41   0:00 -bash
# zirconix   242  0.0  0.0  15520  1876 tty1     R    13:53   0:00 ps aux --sort -rss
# root         1  0.0  0.0   8980   440 ?        Ssl  13:10   0:00 /init
# root       218  0.0  0.0   9328   248 tty2     Ss   13:41   0:00 /init
# root       110  0.0  0.0   9320   244 tty1     Ss   13:23   0:00 /init
# ```

# %% [markdown]
# ### Question 3-14

# %% [markdown]
# ```text
# zirconix@Karakum:~$ python3
# Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>> import sys
# >>> sys.float_info.min
# 2.2250738585072014e-308
# >>> sys.float_info.max
# 1.7976931348623157e+308
# >>> sys.float_info
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)
# ```

# %% [markdown]
# ### Question 3-15

# %%
import np
import matplotlib.pyplot as plt

x1,y1 = np.loadtxt("data/energy-check-argon-nve-rlist09.xvg",comments=["#","@"],unpack=True)
x2,y2 = np.loadtxt("data/energy-check-argon-nve-rlist10.xvg",comments=["#","@"],unpack=True)

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(x1, y1, s=1, marker='x', label='GROtesk MACabre and Sinister')
ax1.scatter(x2, y2, s=1, marker='x', label='Grunge ROck MAChoS')
ax1.legend()

ax1.set_title('GROMACS Energies')
ax1.set_xlabel('Time (ps)')
ax1.set_ylabel('Total Energy (kJ/mol)')
# Out:
# Text(0, 0.5, 'Total Energy (kJ/mol)')

# %% [markdown]
# ### Question 3-16

# %% [markdown]
# Choice of method is `LinearRegression` from the skit-learn library. This is a very straightforward way to get the linear regression parameters and plot them.

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

model = LinearRegression()

fig = plt.figure()
ax1 = fig.add_subplot(111)

x1c = sm.add_constant(x1)
model1 = sm.OLS(y1, x1c)
results1 = model1.fit()

x2c = sm.add_constant(x2)
model2 = sm.OLS(y2, x2c)
results2 = model2.fit()

b1, m1 = results1.params
b2, m2 = results2.params

ax1.scatter(x1, y1, s=1, label="GROtesk MACabre and Sinister")
model.fit(x1.reshape((-1, 1)), y1)
ax1.plot(
    x1,
    [m1 * x + b1 for x in x1],
    linestyle="solid",
    linewidth=1,
    label="Fit to GROtesk MACabre and Sinister",
    c="#000e7d",
)

ax1.scatter(x2, y2, s=1, marker="x", label="Grunge ROck MAChoS")
model.fit(x2.reshape((-1, 1)), y2)
ax1.plot(
    x2,
    [m2 * x + b2 for x in x2],
    linestyle="solid",
    linewidth=1,
    label="Fit to Grunge ROck MAChoS",
    c="#6b2d00",
)

# ax1.plot(x2,y2, label='Grunge ROck MAChoS')
ax1.legend()

ax1.set_title("GROMACS Energies")
ax1.set_xlabel("Time (ps)")
ax1.set_ylabel("Total Energy (kJ/mol)")
# Out:
# Text(0, 0.5, 'Total Energy (kJ/mol)')

# %% [markdown]
# ### Question 3-17

# %% [markdown]
# The statistical parameters of linear regression for the file [nve-rlist09](data/energy-check-argon-nve-rlist09.xvg):

# %%
results1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.854e+06
# Date:                Mon, 05 Feb 2024   Prob (F-statistic):               0.00
# Time:                        21:59:16   Log-Likelihood:                 5112.0
# No. Observations:                2001   AIC:                        -1.022e+04
# Df Residuals:                    1999   BIC:                        -1.021e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        370.8002      0.001   4.41e+05      0.000     370.799     370.802
# ...

# %% [markdown]
# The statistical parameters of linear regression for the file [nve-rlist10](data/energy-check-argon-nve-rlist10.xvg):

# %%
results2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.200
# Method:                 Least Squares   F-statistic:                     500.5
# Date:                Mon, 05 Feb 2024   Prob (F-statistic):           4.02e-99
# Time:                        21:59:16   Log-Likelihood:                 7566.6
# No. Observations:                2001   AIC:                        -1.513e+04
# Df Residuals:                    1999   BIC:                        -1.512e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        370.7966      0.000    1.5e+06      0.000     370.796     370.797
# ...

# %% [markdown]
# ### Question 3-18

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from fitter import Fitter, get_common_distributions, get_distributions

data = np.abs(y2 - np.fromiter((m2 * x + b2 for x in x2), float))

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.hist(data, bins=20, rwidth=0.9, label="Grunge ROck MAChoS")
ax1.legend()
ax1.set_xlabel("Deviation in Energy from fit (kJ/mol)")
ax1.set_ylabel("Count")
ax1.set_title("Distribution of deviations from linear regression fit")

f = Fitter(
    data,
    distributions=[
        "gamma",
        "lognorm",
        "beta",
        "norm",
        "binomial",
        "expon",
        "halfnorm",
    ],
)
fit = f.fit()
best = f.get_best(method="sumsquare_error")
# Out:
# 2024-02-05 22:00:00.812 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED binomial distribution (taking more than 30 seconds)
# 2024-02-05 22:00:00.827 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=71564.707367)
# 2024-02-05 22:00:00.833 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=57344.786613)
# 2024-02-05 22:00:00.862 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=38713.498646)
# 2024-02-05 22:00:00.957 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfnorm distribution with error=22782.891139)
# 2024-02-05 22:00:00.971 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=37762.173491)
# 2024-02-05 22:00:00.997 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted beta distribution with error=28696.586703)

# %%
summary = f.summary()
best
# Out:
# {'halfnorm': {'loc': 3.402914551780041e-06, 'scale': 0.00551235957912451}}

# %%
xmax = data.max()
xx = np.linspace(0, xmax, 50)[1:]

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.hist(data, bins=40, rwidth=0.9, label="Grunge ROck MAChoS")
ax1.legend()
ax1.set_xlabel("Deviation in Energy from fit (kJ/mol)")
ax1.set_ylabel("Count")
ax1.set_title("Distribution of deviations from linear regression fit")
ax1.plot(xx, stats.halfnorm.pdf(xx, **best['halfnorm']))

# %% [markdown]
# Compared to the other distributions that were tested, the halfnorm distribution (which is actually just the Gaussian distribution centered at zero) displays the best fit overall from the sum of squares error:
# $$
# \sum^n_{i=1} (y_i - \bar{y})^2,
# $$
#
# Although the data has some variations that seem to diverge, the halfnorm distribution exhibits good qualitative correspondence overall.
#
# Actually the halfnorm distribution is actually just the Maxwell distribution:
#
# $$
# \mathcal{P}(E) \sim \frac{\sqrt{2/\pi}}{A} \exp(-E^2/A^2),
# $$
# where
# $$
# A=\frac{m}{2 k_{b}T}
# $$
#
# > $A$ is computed to be $5.5123\times 10^{-3}$ by fitting algorithm.
#
# The result (that the Maxwell distribution fits the best) makes sense because, in the context of particle dynamics, these variations represent thermal fluctuations, and they follow a probability equal to the Maxwell distribution.
